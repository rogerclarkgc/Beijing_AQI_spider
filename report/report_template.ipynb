# %%
# %matplotlib inline
import time
import sys
import os
from task.data import DataDrawer
from task.data import air_report
mypath = os.getcwd()
mypath = "{}\\task\\".format(mypath)
sys.path.append(mypath)

current_time = time.localtime(time.time())

DATABASE = "test"
COLLECTION = "air"

# %%
air_summary = air_report(database=DATABASE,
                              collection=COLLECTION,
                              pollutants=['AQI','PM25','SO2','NO2','O3', 'CO', 'PM10'],
                              date='2019-04-20')
# Out:
# Try to connect to local database

# %%
air_summary['filelist']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-22cce6f07a02> in <module>
# ----> 1 air_summary['filelist']
#
# TypeError: list indices must be integers or slices, not str
